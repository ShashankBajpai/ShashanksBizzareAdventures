# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashankBajpai/ShashanksBizzareAdventures/blob/master/Analytics_vidhya2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.names
# !wget archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# Out:
# --2020-05-31 15:00:14--  http://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.names
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6304 (6.2K) [application/x-httpd-php]
# Saving to: ‘UCI HAR Dataset.names’
#
# UCI HAR Dataset.nam 100%[===================>]   6.16K  --.-KB/s    in 0s
#
# 2020-05-31 15:00:14 (339 MB/s) - ‘UCI HAR Dataset.names’ saved [6304/6304]
#
# --2020-05-31 15:00:26--  http://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60999314 (58M) [application/x-httpd-php]
# Saving to: ‘UCI HAR Dataset.zip’
#
# ...

# %%
# !unzip "/content/UCI HAR Dataset.zip"
# Out:
# Archive:  /content/UCI HAR Dataset.zip
#    creating: UCI HAR Dataset/
#   inflating: UCI HAR Dataset/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/UCI HAR Dataset/
#   inflating: __MACOSX/UCI HAR Dataset/._.DS_Store
#   inflating: UCI HAR Dataset/activity_labels.txt
#   inflating: __MACOSX/UCI HAR Dataset/._activity_labels.txt
#   inflating: UCI HAR Dataset/features.txt
#   inflating: __MACOSX/UCI HAR Dataset/._features.txt
#   inflating: UCI HAR Dataset/features_info.txt
#   inflating: __MACOSX/UCI HAR Dataset/._features_info.txt
#   inflating: UCI HAR Dataset/README.txt
#   inflating: __MACOSX/UCI HAR Dataset/._README.txt
#    creating: UCI HAR Dataset/test/
#    creating: UCI HAR Dataset/test/Inertial Signals/
#   inflating: UCI HAR Dataset/test/Inertial Signals/body_acc_x_test.txt
#    creating: __MACOSX/UCI HAR Dataset/test/
#    creating: __MACOSX/UCI HAR Dataset/test/Inertial Signals/
# ...

# %%
import os
file = open("/content/UCI HAR Dataset/features.txt","r")
str = file.read()
big_one = []
smol_str = ""
for i in str:
  if(i != "\n"):
    smol_str = smol_str + i
  else:
    big_one.append(smol_str)
    smol_str = ""

big_one
# Out:
# ['1 tBodyAcc-mean()-X',
#  '2 tBodyAcc-mean()-Y',
#  '3 tBodyAcc-mean()-Z',
#  '4 tBodyAcc-std()-X',
#  '5 tBodyAcc-std()-Y',
#  '6 tBodyAcc-std()-Z',
#  '7 tBodyAcc-mad()-X',
#  '8 tBodyAcc-mad()-Y',
#  '9 tBodyAcc-mad()-Z',
#  '10 tBodyAcc-max()-X',
#  '11 tBodyAcc-max()-Y',
#  '12 tBodyAcc-max()-Z',
#  '13 tBodyAcc-min()-X',
#  '14 tBodyAcc-min()-Y',
#  '15 tBodyAcc-min()-Z',
#  '16 tBodyAcc-sma()',
#  '17 tBodyAcc-energy()-X',
#  '18 tBodyAcc-energy()-Y',
#  '19 tBodyAcc-energy()-Z',
#  '20 tBodyAcc-iqr()-X',
#  '21 tBodyAcc-iqr()-Y',
#  '22 tBodyAcc-iqr()-Z',
#  '23 tBodyAcc-entropy()-X',
#  '24 tBodyAcc-entropy()-Y',
#  '25 tBodyAcc-entropy()-Z',
#  '26 tBodyAcc-arCoeff()-X,1',
#  '27 tBodyAcc-arCoeff()-X,2',
#  '28 tBodyAcc-arCoeff()-X,3',
#  '29 tBodyAcc-arCoeff()-X,4',
#  '30 tBodyAcc-arCoeff()-Y,1',
#  '31 tBodyAcc-arCoeff()-Y,2',
#  '32 tBodyAcc-arCoeff()-Y,3',
#  '33 tBodyAcc-arCoeff()-Y,4',
#  '34 tBodyAcc-arCoeff()-Z,1',
#  '35 tBodyAcc-arCoeff()-Z,2',
# ...

# %%
import pandas as pd
import numpy as np
x = pd.read_csv("/content/UCI HAR Dataset/train/X_train.txt",names = big_one,delim_whitespace = True)
x
# Out:
#       1 tBodyAcc-mean()-X  ...  561 angle(Z,gravityMean)
# 0                0.288585  ...                 -0.058627
# 1                0.278419  ...                 -0.054317
# 2                0.279653  ...                 -0.049118
# 3                0.279174  ...                 -0.047663
# 4                0.276629  ...                 -0.043892
# ...                   ...  ...                       ...
# 7347             0.299665  ...                  0.049819
# 7348             0.273853  ...                  0.050053
# 7349             0.273387  ...                  0.040811
# 7350             0.289654  ...                  0.025339
# 7351             0.351503  ...                  0.036695
#
# [7352 rows x 561 columns]

# %%
#chi2 test only works for discrete data
from sklearn.feature_selection import chi2
from scipy.stats import chi2_contingency
ans = 
ans
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-af26e7f493a6> in <module>()
#       1 from sklearn.feature_selection import chi2
# ----> 2 ans = chi2(x,y)
#       3 ans
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_selection/_univariate_selection.py in chi2(X, y)
#     214     X = check_array(X, accept_sparse='csr')
#     215     if np.any((X.data if issparse(X) else X) < 0):
# --> 216         raise ValueError("Input X must be non-negative.")
#     217
#     218     Y = LabelBinarizer().fit_transform(y)
#
# ValueError: Input X must be non-negative.

# %%
y = pd.read_csv("/content/UCI HAR Dataset/train/y_train.txt",names = ["Class"])
print(type(y["Class"]))
y = pd.to_numeric(y["Class"])
y
# Out:
# <class 'pandas.core.series.Series'>
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 7347    2
# 7348    2
# 7349    2
# 7350    2
# 7351    2
# Name: Class, Length: 7352, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for i in x.columns:
  plt.scatter(x[i],y)
  plt.xlabel(i)
  plt.ylabel("Target Class")
  plt.show()

#From the given graph we can say that one variable alone cant determine uniquely the target variable

# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
for num in range(0,558):
  fig = plt.figure()
  ax = Axes3D(fig)
  ax.scatter(xs = x.iloc[:,num],ys = x.iloc[:,num+1],zs = x.iloc[:,num+2],c = y,depthshade = True)
  ax.set_xlabel("X")
  ax.set_ylabel("Y")
  ax.set_zlabel("Z")
  plt.show()
print()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
model4 = LogisticRegression()
params = {'penalty':('none','l2'),'C':(0.1,0.01),'class_weight':(None,'balanced'),'max_iter':(10000,5000)}
rs = GridSearchCV(model4,params)
rs.fit(x,y)
rs.cv_results_
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# ...

# %%
print(rs.best_estimator_)
print(rs.best_score_)
print(rs.best_params_)
#0.96 without these combinations of parameters
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# 0.9314535440280803
# {'C': 0.1, 'class_weight': None, 'max_iter': 10000, 'penalty': 'l2'}

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier().fit(x,y)

# %%
from sklearn.linear_model import LogisticRegression
model2 = LogisticRegression(max_iter = 20000).fit(x,y)

# %%
from sklearn.svm import SVC
model3 = SVC().fit(x,y)

# %%
x_test = pd.read_csv("/content/UCI HAR Dataset/test/X_test.txt",names = big_one,delim_whitespace = True)
x_test
# Out:
#       1 tBodyAcc-mean()-X  ...  561 angle(Z,gravityMean)
# 0                0.257178  ...                 -0.057978
# 1                0.286027  ...                 -0.083898
# 2                0.275485  ...                 -0.079346
# 3                0.270298  ...                 -0.077108
# 4                0.274833  ...                 -0.073857
# ...                   ...  ...                       ...
# 2942             0.310155  ...                  0.184784
# 2943             0.363385  ...                  0.182412
# 2944             0.349966  ...                  0.181184
# 2945             0.237594  ...                  0.187563
# 2946             0.153627  ...                  0.188103
#
# [2947 rows x 561 columns]

# %%
y_test = pd.read_csv("/content/UCI HAR Dataset/test/y_test.txt",names = ["Class"])
y_test.shape
# Out:
# (2947, 1)

# %%
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score
y_pred = model2.predict(x_test)
acc = accuracy_score(y_test,y_pred)
print(acc)
#without using parameters from grid search 0.96
#2nd attempt 0.95
# Out:
# 0.9613165931455717

# %%
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score
y_pred = model.predict(x_test)
acc = accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.8625721072276892

# %%
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score
y_pred = model3.predict(x_test)
acc = accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.9504580929759077
